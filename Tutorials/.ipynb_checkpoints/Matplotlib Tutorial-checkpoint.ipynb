# %% [markdown]
# # Matplotlib Tutorial by [Ali Abdelaal](https://www.linkedin.com/in/aliabdelaal/)
# ### this tutorial file was made for [Pixels](https://www.facebook.com/PixelsHU/) Course (Machine Learning)
# ## Let's Start by installing pandas
# ### use the following
# sudo apt-get install python-pip
# sudo pip install matplotlib
# ### now include the library
# import matplotlib.plot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### using this command to show plots in the notebook

# %%
# %matplotlib inline

# %% [markdown]
# ## let's import the data and start visualizing it

# %%
dataset = pd.read_csv('Position_Salaries.csv')
dataset
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# ### let's start by drawing just the salaries vs the level

# %%
salaries = dataset.iloc[:,-1].values
levels = dataset.iloc[:, -2].values
plt.plot(salaries,levels)
plt.show()

# %% [markdown]
# ### What about the opposite ?

# %%
plt.plot(levels, salaries)
plt.show()

# %% [markdown]
# #### we can easly see that the plot takes the x-axis values as the first argument then the y-axis by looking at the above example

# %% [markdown]
# ## We can change the shape of the relation !

# %%
plt.plot(levels, salaries, 'ro')
plt.show()

# %%
plt.plot(levels, salaries, linewidth = 7.0)
plt.show()

# %% [markdown]
# ## Naming your axis is so important dude !

# %%
plt.plot(levels, salaries)
plt.xlabel('level')
plt.ylabel('salary')
plt.title('levels vs salary !')
plt.show()

# %% [markdown]
# ## Now let's make a new different salaries and compare them with our salaries

# %%
someLargeNumber = 90000
new_salaries = salaries + (np.random.rand(np.shape(salaries)[0]) * someLargeNumber )
new_salaries
# Out:
# array([   50104.15250729,   132334.49019447,    85246.85429858,
#          119233.96070055,   120691.78387226,   194848.51529705,
#          276158.91879211,   353234.82114603,   512606.46233566,
#         1014606.74602585])

# %% [markdown]
# ### Let's take a look to our new data

# %%
plt.plot(levels, new_salaries)
plt.show()

# %% [markdown]
# ### Now let's compare them together

# %%
plt.plot(levels, salaries, levels, new_salaries)
plt.show()

# %% [markdown]
# ### Notice that the new salaries are always above the salaries as we added a random values to it

# %% [markdown]
# ## Again that's it for now, but there's much much more to know out there !
# ### you can learn much more from the documentation of the library itself [here](https://matplotlib.org/users/pyplot_tutorial.html)
