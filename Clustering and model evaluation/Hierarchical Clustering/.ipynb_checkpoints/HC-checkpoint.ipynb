# %% [markdown]
# # HC Clustering Tutorial by [Ali Abdelaal](https://www.linkedin.com/in/aliabdelaal/)
# ### this tutorial file was made for [Pixels](https://www.facebook.com/PixelsHU/) Course (Machine Learning)

# %%
# import the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read our dataset
dataset = pd.read_csv('Mall_Customers.csv')
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
features = dataset.iloc[:, 1:].values

# solve categorical data
# solve the categorical data
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
features[:,0] = encoder.fit_transform(features[:,0])

pd.DataFrame(features)
# Out:
#      0   1    2   3
# 0    1  19   15  39
# 1    1  21   15  81
# 2    0  20   16   6
# 3    0  23   16  77
# 4    0  31   17  40
# 5    0  22   17  76
# 6    0  35   18   6
# 7    0  23   18  94
# 8    1  64   19   3
# 9    0  30   19  72
# 10   1  67   19  14
# 11   0  35   19  99
# 12   0  58   20  15
# 13   0  24   20  77
# 14   1  37   20  13
# 15   1  22   20  79
# 16   0  35   21  35
# 17   1  20   21  66
# 18   1  52   23  29
# 19   0  35   23  98
# 20   1  35   24  35
# 21   1  25   24  73
# 22   0  46   25   5
# 23   1  31   25  73
# 24   0  54   28  14
# 25   1  29   28  82
# 26   0  45   28  32
# 27   1  35   28  61
# 28   0  40   29  31
# 29   0  23   29  87
# ..  ..  ..  ...  ..
# 170  1  40   87  13
# 171  1  28   87  75
# 172  1  36   87  10
# 173  1  36   87  92
# 174  0  52   88  13
# 175  0  30   88  86
# 176  1  58   88  15
# 177  1  27   88  69
# 178  1  59   93  14
# 179  1  35   93  90
# 180  0  37   97  32
# 181  0  32   97  86
# 182  1  46   98  15
# ...

# %% [markdown]
# ## Time for the HC

# %%
# Fitting Hierarchical Clustering to the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(features)

# %%
plt.scatter(features[y_hc == 0, 2], features[y_hc == 0, -1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(features[y_hc == 1, 2], features[y_hc == 1, -1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(features[y_hc == 2, 2], features[y_hc == 2, -1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(features[y_hc == 3, 2], features[y_hc == 3, -1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(features[y_hc == 4, 2], features[y_hc == 4, -1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ## But how did we know that 5 is the number ?
# ### no, not from the previuos tutorial :P

# %% [markdown]
# # Dendrograms

# %% [markdown]
# ### Dendrograms is like a memory for the HC, it keep track of the splitting so that we can see where to stop splitting
# ### let's take a look

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(features, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# ## Feel free to change the number of clustering and see how the HC will do !
